# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from transformers import AutoTokenizer

models = [
    "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T",
    "Qwen/Qwen2.5-7B",
    "meta-llama/Llama-3.1-8B"
]
terms = [
    "atorvastatin",
    "pharmacovigilance",
    "transcriptomics",
    "phosphatidylinositol"
]

for model in models:
    tok = AutoTokenizer.from_pretrained(model)
    print(f"\n{model}")

    for term in terms:
        tokens = tok.tokenize(term)
        print(term, len(tokens), tokens)
# Out:
# TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T
# atorvastatin 5 ['▁at', 'or', 'v', 'ast', 'atin']
# pharmacovigilance 7 ['▁ph', 'arm', 'ac', 'ov', 'ig', 'il', 'ance']
# transcriptomics 4 ['▁trans', 'cript', 'om', 'ics']
# phosphatidylinositol 9 ['▁ph', 'osph', 'at', 'id', 'y', 'lin', 'os', 'it', 'ol']
#
# Qwen/Qwen2.5-7B
# atorvastatin 4 ['ator', 'v', 'ast', 'atin']
# pharmacovigilance 6 ['ph', 'armac', 'ov', 'ig', 'il', 'ance']
# transcriptomics 3 ['trans', 'cript', 'omics']
# phosphatidylinositol 7 ['ph', 'osph', 'at', 'idy', 'lin', 'os', 'itol']
#
# meta-llama/Llama-3.1-8B
# atorvastatin 4 ['ator', 'v', 'ast', 'atin']
# pharmacovigilance 6 ['ph', 'armac', 'ov', 'ig', 'il', 'ance']
# transcriptomics 3 ['trans', 'cript', 'omics']
# phosphatidylinositol 7 ['ph', 'osph', 'at', 'idy', 'lin', 'os', 'itol']
